# %%
# !pip install "torch==1.4" "torchvision==0.5.0"
# Out:
# Collecting torch==1.4
#   Downloading https://files.pythonhosted.org/packages/24/19/4804aea17cd136f1705a5e98a00618cb8f6ccc375ad8bfa437408e09d058/torch-1.4.0-cp36-cp36m-manylinux1_x86_64.whl (753.4MB)
#      |████████████████████████████████| 753.4MB 22kB/s
# Collecting torchvision==0.5.0
#   Downloading https://files.pythonhosted.org/packages/7e/90/6141bf41f5655c78e24f40f710fdd4f8a8aff6c8b7c6f0328240f649bdbe/torchvision-0.5.0-cp36-cp36m-manylinux1_x86_64.whl (4.0MB)
#      |████████████████████████████████| 4.0MB 49.1MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision==0.5.0) (1.12.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision==0.5.0) (1.18.3)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision==0.5.0) (7.0.0)
# Installing collected packages: torch, torchvision
#   Found existing installation: torch 1.5.0+cu101
#     Uninstalling torch-1.5.0+cu101:
#       Successfully uninstalled torch-1.5.0+cu101
#   Found existing installation: torchvision 0.6.0+cu101
#     Uninstalling torchvision-0.6.0+cu101:
#       Successfully uninstalled torchvision-0.6.0+cu101
# Successfully installed torch-1.4.0 torchvision-0.5.0

# %%
# !curl -s https://course.fast.ai/setup/colab | bash
# Out:
# Updating fastai...
# Done.

# %%
from fastai.vision import *

# %%
folder = 'black'
file = 'urls_black.txt'

# %%
path = Path('data/bears')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
download_images(path/file, dest, max_pics=200)
# Out:
# Error https://www.washingtonpost.com/resizer/8oTEoyrrxY092B3yebDUUAdQLdM=/480x0/arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/XK6YBT5GSE2LROLN3FO4WRK5JI.jpg HTTPSConnectionPool(host='www.washingtonpost.com', port=443): Read timed out. (read timeout=4)
# Error https://img-realtree.com/sites/default/files/styles/site_large/public/content/inserts/realtree-bear-hunting-imagesonthewildside-blackbear.jpg?itok=ItV2_hr- HTTPSConnectionPool(host='img-realtree.com', port=443): Max retries exceeded with url: /sites/default/files/styles/site_large/public/content/inserts/realtree-bear-hunting-imagesonthewildside-blackbear.jpg?itok=ItV2_hr- (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f3b1940b668>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error http://aep.alberta.ca/fish-wildlife/wild-species/mammals/bears/images/GFX-Black-Bear-01.jpg HTTPConnectionPool(host='aep.alberta.ca', port=80): Max retries exceeded with url: /fish-wildlife/wild-species/mammals/bears/images/GFX-Black-Bear-01.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f3b194331d0>: Failed to establish a new connection: [Errno -5] No address associated with hostname',))
# Error https://www.wildlife.ca.gov/portals/0/Images/OCEO/KeepMeWild/kmw-black-bear.jpg HTTPSConnectionPool(host='www.wildlife.ca.gov', port=443): Max retries exceeded with url: /portals/0/Images/OCEO/KeepMeWild/kmw-black-bear.jpg (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f3b19432668>, 'Connection to www.wildlife.ca.gov timed out. (connect timeout=4)'))
# Error https://www.langleyadvance.com/wp-content/uploads/2018/08/13207973_web1_180706-SNM-M-Black-Bear-2.jpg HTTPSConnectionPool(host='www.langleyadvance.com', port=443): Max retries exceeded with url: /wp-content/uploads/2018/08/13207973_web1_180706-SNM-M-Black-Bear-2.jpg (Caused by SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),))
# Error https://news.nationalgeographic.com/content/dam/news/2017/07/10/north-american-black-bear/01-black-bear.ngsversion.1499974343066.adapt.1900.1.jpg HTTPSConnectionPool(host='www.nationalgeographic.com', port=443): Read timed out. (read timeout=4)
# Error x-raw-image:///08a30e8397a4e0ab7620c2efb00097f48e46778ccc9714c8c32e5dac9a16e3e9 No connection adapters were found for 'x-raw-image:///08a30e8397a4e0ab7620c2efb00097f48e46778ccc9714c8c32e5dac9a16e3e9'
# Error http://blackbearinfo.com/blackbear/wp-content/uploads/2013/07/blacklooks.jpg HTTPConnectionPool(host='blackbearinfo.com', port=80): Max retries exceeded with url: /blackbear/wp-content/uploads/2013/07/blacklooks.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f3b1940bcc0>, 'Connection to blackbearinfo.com timed out. (connect timeout=4)'))
# Error http://blackbearinfo.com/blackbear/wp-content/uploads/2013/07//ManFitesBear.jpg HTTPConnectionPool(host='blackbearinfo.com', port=80): Max retries exceeded with url: /blackbear/wp-content/uploads/2013/07//ManFitesBear.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f3b1941f400>, 'Connection to blackbearinfo.com timed out. (connect timeout=4)'))

# %%
folder = 'teddys'
file = 'urls_teddys.txt'

# %%
path = Path('data/bears')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
download_images(path/file, dest, max_pics=200)
# Out:
# Error https://cdn.apkaabazar.com/wp-content/uploads/2018/05/8-compressed.jpg HTTPSConnectionPool(host='cdn.apkaabazar.com', port=443): Max retries exceeded with url: /wp-content/uploads/2018/05/8-compressed.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f3b1943bf98>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error https://www.vermontteddybear.com/media/wysiwyg/vtb-hero-images/vtb-homepage-hero1-20180302.png HTTPSConnectionPool(host='www.vermontteddybear.com', port=443): Read timed out. (read timeout=4)
# Error https://www.sendah.com/988-thickbox_default/daydream-white-teddy-bear.jpg HTTPSConnectionPool(host='www.sendah.com', port=443): Max retries exceeded with url: /988-thickbox_default/daydream-white-teddy-bear.jpg (Caused by SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)'),))
# Error https://images.pexels.com/photos/159080/still-life-teddy-white-read-159080.jpeg?cs=srgb&dl=baby-book-child-159080.jpg&fm=jpg HTTPSConnectionPool(host='images.pexels.com', port=443): Read timed out. (read timeout=4)
# Error https://tinysurprise.com/media/catalog/product/cache/1/small_image/9df78eab33525d08d6e5fb8d27136e95/w/h/white_teddy_giant.jpg HTTPSConnectionPool(host='tinysurprise.com', port=443): Max retries exceeded with url: /media/catalog/product/cache/1/small_image/9df78eab33525d08d6e5fb8d27136e95/w/h/white_teddy_giant.jpg (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f3b183dd320>, 'Connection to tinysurprise.com timed out. (connect timeout=4)'))
# Error https://tinysurprise.com/media/catalog/product/cache/1/small_image/9df78eab33525d08d6e5fb8d27136e95/3/3/33.jpg HTTPSConnectionPool(host='tinysurprise.com', port=443): Max retries exceeded with url: /media/catalog/product/cache/1/small_image/9df78eab33525d08d6e5fb8d27136e95/3/3/33.jpg (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f3b19474f60>, 'Connection to tinysurprise.com timed out. (connect timeout=4)'))

# %%
folder = 'grizzly'
file = 'urls_grizzly.txt'

# %%
path = Path('data/bears')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
path.ls()
# Out:
# [PosixPath('data/bears/grizzly'),
#  PosixPath('data/bears/urls_black.txt'),
#  PosixPath('data/bears/black'),
#  PosixPath('data/bears/urls_grizzly.txt'),
#  PosixPath('data/bears/urls_teddys.txt'),
#  PosixPath('data/bears/teddys')]

# %%
classes = ['teddys','grizzly','black']

# %%
download_images(path/file, dest, max_pics=200)
# Out:
# Error https://www.nationalgeographic.com/content/dam/animals/thumbs/rights-exempt/mammals/g/grizzly-bear_thumb.ngsversion.1484681402665.adapt.1900.1.JPG HTTPSConnectionPool(host='www.nationalgeographic.com', port=443): Read timed out. (read timeout=4)
# Error https://thumbs-prod.si-cdn.com/HuW0pgC87C9GNODfExrT_mLJARo=/800x600/filters:no_upscale()/https://public-media.si-cdn.com/filer/4c/0d/4c0deb1e-5a0b-417b-8074-d1e9bc3e7eaf/nov2017_a04_grizzlies.jpg HTTPSConnectionPool(host='thumbs-prod.si-cdn.com', port=443): Read timed out. (read timeout=4)
# Error https://blog.patagonia.com/wp-content/uploads/2018/04/gnam_s_0089_1600TCL-1404x778-c-default.jpg HTTPSConnectionPool(host='blog.patagonia.com', port=443): Max retries exceeded with url: /wp-content/uploads/2018/04/gnam_s_0089_1600TCL-1404x778-c-default.jpg (Caused by SSLError(CertificateError("hostname 'blog.patagonia.com' doesn't match either of '*.wpengine.com', 'wpengine.com'",),))
# Error https://icdn2.themanual.com/image/themanual/grizzly-bear-attacking-fish.jpg HTTPSConnectionPool(host='icdn2.themanual.com', port=443): Read timed out. (read timeout=4)
# Error https://www.washingtonpost.com/resizer/S2qpHxfmuc7JUINSZp4pd8_N7m4=/480x0/arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/AUEKO7HTGII6RGOCZ7FG7T3BBQ.jpg HTTPSConnectionPool(host='www.washingtonpost.com', port=443): Read timed out. (read timeout=4)
# Error https://news.nationalgeographic.com/content/dam/news/2015/08/20/bearcourt/1bearcourt.ngsversion.1440099001838.adapt.1900.1.jpg HTTPSConnectionPool(host='www.nationalgeographic.com', port=443): Read timed out. (read timeout=4)
# Error https://www.washingtonpost.com/resizer/rNWQ6oDst_gqJ_khkSXYRtftUz4=/1484x0/arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/Q453GZ66JEZEZFGRDAJEPKT254.png HTTPSConnectionPool(host='www.washingtonpost.com', port=443): Read timed out. (read timeout=4)
# Error http://aep.alberta.ca/fish-wildlife/wild-species/mammals/bears/images/GFX-Grizzly-01.jpg HTTPConnectionPool(host='aep.alberta.ca', port=80): Max retries exceeded with url: /fish-wildlife/wild-species/mammals/bears/images/GFX-Grizzly-01.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f3b183dd518>: Failed to establish a new connection: [Errno -5] No address associated with hostname',))
# Error https://www.washingtonpost.com/pbox.php?url=http://www.washingtonpost.com/news/animalia/wp-content/uploads/sites/56/2016/06/cub1.jpg&w=1484&op=resize&opt=1&filter=antialias&t=20170517 HTTPSConnectionPool(host='www.washingtonpost.com', port=443): Read timed out. (read timeout=4)

# %%
download_images(path/file, dest, max_pics=20, max_workers=0)
# Out:
# Error https://www.washingtonpost.com/resizer/8oTEoyrrxY092B3yebDUUAdQLdM=/480x0/arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/XK6YBT5GSE2LROLN3FO4WRK5JI.jpg HTTPSConnectionPool(host='www.washingtonpost.com', port=443): Read timed out. (read timeout=4)

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=500)
# Out:
# teddys
# grizzly
# black

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,ds_tfms=get_transforms(), size=64, num_workers=0).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['black', 'grizzly', 'teddys']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['black', 'grizzly', 'teddys'], 3, 397, 99)

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# HBox(children=(IntProgress(value=0, max=87306240), HTML(value='')))

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.490274</td>
#       <td>0.363449</td>
#       <td>0.070707</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.977657</td>
#       <td>0.214280</td>
#       <td>0.050505</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.785192</td>
#       <td>0.260018</td>
#       <td>0.060606</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.636526</td>
#       <td>0.300248</td>
#       <td>0.090909</td>
#       <td>00:04</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='14' class='' max='17' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       82.35% [14/17 00:47<00:10]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.405816</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.358007</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.331654</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.359370</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.369512</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.346897</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.322062</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.297067</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.291944</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.309050</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.400742</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.506592</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.582811</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.946697</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='6' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       16.67% [1/6 00:00<00:02 1.0396]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(2, max_lr=slice(3e-5,3e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.412377</td>
#       <td>0.352169</td>
#       <td>0.080808</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.320726</td>
#       <td>0.426802</td>
#       <td>0.101010</td>
#       <td>00:04</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2')

# %%
learn.load('stage-2');

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
from fastai.widgets import *

# %%
db = (ImageList.from_folder(path)
                   .split_none()
                   .label_from_folder()
                   .transform(get_transforms(), size=224)
                   .databunch()
     )

# %%
learn_cln = cnn_learner(db, models.resnet34, metrics=error_rate)

learn_cln.load('stage-2');

# %%
ds, idxs = DatasetFormatter().from_toplosses(learn_cln)

# %%
ImageCleaner(ds, idxs, path)
# Out:
# 'No images to show :)'

# %%
ds, idxs = DatasetFormatter().from_similars(learn_cln)
# Out:
# Getting activations...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8' class='' max='8' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8/8 00:05<00:00]
#     </div>
# Computing similarities...

# %%
ImageCleaner(ds, idxs, path, duplicates=True)
# Out:
# HBox(children=(VBox(children=(Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00d\x00d\x00\x00\xff…
# Button(button_style='primary', description='Next Batch', layout=Layout(width='auto'), style=ButtonStyle())

# %%
learn.export()

# %%
defaults.device = torch.device('cpu')

# %%
img = open_image(path/'black'/'00000002.jpg')
img
# Out:
# Image (3, 294, 500)

# %%
learn = load_learner(path)

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class
# Out:
# Category tensor(0)

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(1, max_lr=0.5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>12.742925</td>
#       <td>322736672.000000</td>
#       <td>0.747475</td>
#       <td>00:03</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(5, max_lr=1e-5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.163923</td>
#       <td>2.232647</td>
#       <td>0.646465</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.165026</td>
#       <td>1.730591</td>
#       <td>0.595960</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.143276</td>
#       <td>1.521775</td>
#       <td>0.585859</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.043837</td>
#       <td>1.439033</td>
#       <td>0.515152</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.000667</td>
#       <td>1.404355</td>
#       <td>0.505050</td>
#       <td>00:03</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate, pretrained=False)

# %%
learn.fit_one_cycle(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.694298</td>
#       <td>0.956570</td>
#       <td>0.353535</td>
#       <td>00:03</td>
#     </tr>
#   </tbody>
# </table>

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.9, bs=32, 
        ds_tfms=get_transforms(do_flip=False, max_rotate=0, max_zoom=1, max_lighting=0, max_warp=0
                              ),size=224, num_workers=4).normalize(imagenet_stats)

# %%
learn = cnn_learner(data, models.resnet50, metrics=error_rate, ps=0, wd=0)
learn.unfreeze()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/checkpoints/resnet50-19c8e357.pth
# HBox(children=(IntProgress(value=0, max=102502400), HTML(value='')))

# %%
learn.fit_one_cycle(40, slice(1e-6,1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.312453</td>
#       <td>1.556586</td>
#       <td>0.771300</td>
#       <td>01:37</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.386484</td>
#       <td>1.512304</td>
#       <td>0.739910</td>
#       <td>01:39</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.312841</td>
#       <td>1.433665</td>
#       <td>0.717489</td>
#       <td>01:39</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.320009</td>
#       <td>1.320428</td>
#       <td>0.663677</td>
#       <td>01:38</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.237474</td>
#       <td>1.174558</td>
#       <td>0.587444</td>
#       <td>01:37</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.140916</td>
#       <td>1.008637</td>
#       <td>0.524664</td>
#       <td>01:37</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.059612</td>
#       <td>0.843073</td>
#       <td>0.419283</td>
#       <td>01:37</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.965783</td>
#       <td>0.682432</td>
#       <td>0.291480</td>
#       <td>01:38</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.885567</td>
#       <td>0.554696</td>
#       <td>0.208520</td>
#       <td>01:39</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.801121</td>
#       <td>0.453435</td>
#       <td>0.154709</td>
#       <td>01:40</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.739156</td>
#       <td>0.369801</td>
#       <td>0.118834</td>
#       <td>01:39</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.678098</td>
#       <td>0.314206</td>
#       <td>0.105381</td>
#       <td>01:40</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.624492</td>
#       <td>0.274881</td>
#       <td>0.096413</td>
#       <td>01:40</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.575385</td>
#       <td>0.242393</td>
#       <td>0.087444</td>
#       <td>01:40</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.533119</td>
#       <td>0.216438</td>
#       <td>0.080717</td>
#       <td>01:40</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.499285</td>
#       <td>0.196306</td>
#       <td>0.065022</td>
#       <td>01:40</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.465978</td>
#       <td>0.182692</td>
#       <td>0.060538</td>
#       <td>01:39</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.436921</td>
#       <td>0.172415</td>
#       <td>0.044843</td>
#       <td>01:40</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.409720</td>
#       <td>0.165869</td>
#       <td>0.042601</td>
#       <td>01:40</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.385565</td>
#       <td>0.159670</td>
#       <td>0.038117</td>
#       <td>01:40</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.363860</td>
#       <td>0.154171</td>
#       <td>0.033632</td>
#       <td>01:40</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.344807</td>
#       <td>0.150861</td>
#       <td>0.038117</td>
#       <td>01:41</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.326535</td>
#       <td>0.148464</td>
#       <td>0.035874</td>
#       <td>01:42</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.309698</td>
#       <td>0.145164</td>
#       <td>0.035874</td>
#       <td>01:41</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.294281</td>
#       <td>0.143203</td>
#       <td>0.035874</td>
#       <td>01:40</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.279963</td>
#       <td>0.142245</td>
#       <td>0.035874</td>
#       <td>01:41</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.267291</td>
#       <td>0.138889</td>
#       <td>0.040359</td>
#       <td>01:43</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.255603</td>
#       <td>0.136914</td>
#       <td>0.038117</td>
#       <td>01:44</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.244219</td>
#       <td>0.134712</td>
#       <td>0.038117</td>
#       <td>01:43</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.233555</td>
#       <td>0.134557</td>
#       <td>0.035874</td>
#       <td>01:43</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.223868</td>
#       <td>0.134164</td>
#       <td>0.035874</td>
#       <td>01:42</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.214597</td>
#       <td>0.135191</td>
#       <td>0.035874</td>
#       <td>01:42</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.205826</td>
#       <td>0.134910</td>
#       <td>0.033632</td>
#       <td>01:41</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.197609</td>
#       <td>0.134445</td>
#       <td>0.035874</td>
#       <td>01:42</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.189985</td>
#       <td>0.133904</td>
#       <td>0.035874</td>
#       <td>01:42</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.182733</td>
#       <td>0.134605</td>
#       <td>0.035874</td>
#       <td>01:40</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.175979</td>
#       <td>0.136641</td>
#       <td>0.035874</td>
#       <td>01:39</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.169518</td>
#       <td>0.138073</td>
#       <td>0.038117</td>
#       <td>01:36</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.163369</td>
#       <td>0.135357</td>
#       <td>0.035874</td>
#       <td>01:35</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.157627</td>
#       <td>0.136543</td>
#       <td>0.038117</td>
#       <td>01:34</td>
#     </tr>
#   </tbody>
# </table>
